# %%
import numpy as np

# %%
#MNIST IID
e = 200
fedavg = [0.009012985229492187, 0.009212875366210937, 0.009216117858886718, 0.009214496612548828, 
          0.009213066101074219, 0.009011268615722656]
print(np.log(np.mean(fedavg)*e))

median = [0.11189761161804199, 0.1104964256286621, 0.11049995422363282, 0.11089911460876464,
         0.11149945259094238, 0.11049890518188477]
print(np.log(np.mean(median)*e))

rmedian = [4.692067098617554, 4.6872608184814455, 4.6766533851623535, 4.690665578842163,  
           4.683257579803467, 4.676454353332519]
print(np.log(np.mean(rmedian)*e))

tmean = [0.009009885787963866, 0.10969934463500977, 0.10969939231872558, 0.10929570198059083, 
         0.10969634056091308,]
print(np.log(np.mean(tmean)*e))

mkrum = [0.030023670196533202, 0.02962632179260254, 0.030422687530517578, 0.02962632179260254,
        0.029225921630859374, 0.029424428939819336]
print(np.log(np.mean(mkrum)*e))

foolsgold = [0.024020624160766602, 0.021869802474975587, 0.018746137619018555, 0.021869707107543945,
            0.024993276596069335, 0.018747758865356446]
print(np.log(np.mean(foolsgold)*e))


ours = [0.13438000679016113, 0.13147335052490233, 0.1322930335998535, 0.1340646266937256,
       0.13511390686035157, 0.1367175579071045]
print(np.log(np.mean(ours)*e))
# Out:
# 0.6039663571847966
# 3.099779122507318
# 6.842553740381127
# 2.8845787111853887
# 1.7825468961744635
# 1.468237621780432
# 3.288454724897134

# %%
#MNIST Extreme
fedavg = [0.009008216857910156, 0.009208345413208007, 0.0038034915924072266, 0.012500619888305664, 0.013865280151367187]
print(np.log(np.mean(fedavg)*e))

median = [0.10937490463256835, 0.10410728454589843, 0.10625147819519043, 0.10937652587890626, 0.10312452316284179,
         0.10274600982666016]
print(np.log(np.mean(median)*e))

rmedian = [4.7544018745422365, 4.739138269424439, 4.7412937641143795, 4.750412845611573, 
           4.733808135986328, 4.72748966217041]
print(np.log(np.mean(rmedian)*e))

tmean = [0.006250429153442383, 0.10625133514404297, 0.10000095367431641, 0.10312771797180176,
        0.10030617713928222]
print(np.log(np.mean(tmean)*e))

mkrum = [0.031247568130493165, 0.03124542236328125, 0.03124551773071289, 0.03124542236328125, 
        0.02812204360961914, 0.03124852180480957]
print(np.log(np.mean(mkrum)*e))

foolsgold = [0.02499675750732422, 0.022899723052978514, 0.024993753433227538, 0.021868562698364256,
            0.02187495231628418, 0.0281191349029541]
print(np.log(np.mean(foolsgold)*e))


ours = [0.10728945732116699, 0.10313272476196289, 0.09688420295715332, 0.09688243865966797, 
        0.09687895774841308, 0.10313272476196289]
print(np.log(np.mean(ours)*e))
# Out:
# 0.6603337381241104
# 3.0523972643951933
# 6.8545845936388385
# 2.8116570513863004
# 1.8156631311241713
# 1.573830657985454
# 3.0027087251092097

# %%
#CIFAR IID
e = 100
fedavg = [0.19491381645202638, 0.19926877021789552, 0.20346012115478515, 0.19443221092224122,
         0.197356653213501, 0.20586004257202148]
print(np.log(np.mean(fedavg)*e))

median = [1.669800329208374, 1.7351324081420898, 1.6480779647827148, 1.604733943939209, 
          1.6830355167388915, 1.726190185546875]
print(np.log(np.mean(median)*e))

rmedian = [79.68501577377319, 79.87533731460572, 80.39498963356019, 80.83273859024048,
          81.15616888999939, 80.66491098403931]
print(np.log(np.mean(rmedian)*e))

tmean = [0.19688501358032226, 1.816341018676758, 1.7226054668426514, 1.8065677165985108,
        1.6758246421813965]
print(np.log(np.mean(tmean)*e))

mkrum = [1.9560251235961914, 2.0123932361602783, 1.936889934539795, 1.9129700660705566,
        1.931117057800293, 1.922866201400757]
print(np.log(np.mean(mkrum)*e))

foolsgold = [0.2856722354888916, 0.27592029571533205, 0.26856579780578616]
print(np.log(np.mean(foolsgold)*e))


ours = [0.8834553718566894, 0.8660780906677246, 0.8812122344970703, 0.8830753326416015, 
        0.8698631763458252, 0.8689429759979248]
print(np.log(np.mean(ours)*e))
# Out:
# 2.991800901270767
# 5.12267051907318
# 8.99261785275094
# 4.972341193131247
# 5.2706259420171815
# 3.3204190587799096
# 4.472139083817777

# %%
#IMDB IID
e = 50
fedavg = [0.26964197158813474, 0.2684410572052002, 0.2728447437286377, 0.2694402694702148]
print(np.log(np.mean(fedavg)*e))

median = [2.0693825483322144, 2.078390955924988, 2.098909616470337]
print(np.log(np.mean(median)*e))

rmedian = [90.59142136573792, 90.60943698883057, 90.63546133041382, 90.96375966072083,
          91.02781820297241, 91.31407833099365]
print(np.log(np.mean(rmedian)*e))

tmean = [0.27124643325805664, 2.312103271484375, 2.1469531059265137, 2.163969039916992, 
        2.077890396118164]
print(np.log(np.mean(tmean)*e))

mkrum = [2.239037036895752, 2.2040047645568848, 2.2080090045928955, 2.215014934539795, 2.2190184593200684, 
        2.2400386333465576]
print(np.log(np.mean(mkrum)*e))

foolsgold = [0.34128904342651367, 0.28526735305786133, 0.3002791404724121,
            0.29527950286865234, 0.2832634449005127, 0.286266565322876]
print(np.log(np.mean(foolsgold)*e))


ours = [0.7336673736572266, 0.7256615161895752, 0.7436766624450684, 0.7416744232177734, 0.7356679439544678, 
       0.7456779479980469]
print(np.log(np.mean(ours)*e))
# Out:
# 2.603030407014592
# 4.645461338953302
# 8.421309803138714
# 4.4967117931603795
# 4.709914724464817
# 2.703397756383898
# 3.6077656222452545
